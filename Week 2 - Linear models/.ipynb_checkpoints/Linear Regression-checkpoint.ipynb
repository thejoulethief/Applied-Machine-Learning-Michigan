# %% [markdown]
# So this is the KNearestNeighbors classifer without normalization. Accuracy seems maximum for K=1, and ranges from 0.6-0.73

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

fruits = pd.read_table("fruit_data_with_colors.txt")

fruits_features=['mass', 'width', 'height', 'color_score']

X_fruits = fruits[fruits_features]

Y_fruits = fruits['fruit_label']
target_names_fruits = ['apple', 'orange', 'mandarin', 'lemon']


X_train, X_test, y_train, y_test = train_test_split(X_fruits, Y_fruits, random_state=0)

score_list=[]

for k in range(1,20):

    knn = KNeighborsClassifier(n_neighbors=k)

    knn.fit(X_train, y_train)

    score = knn.score(X_test, y_test)

    score_list.append(score)
    print("The score for k value of {} was {}".format(k,score))


plt.scatter(range(1,20), score_list, marker='o')
plt.show()
# Out:
# The score for k value of 1 was 0.6
# The score for k value of 2 was 0.5333333333333333
# The score for k value of 3 was 0.5333333333333333
# The score for k value of 4 was 0.5333333333333333
# The score for k value of 5 was 0.5333333333333333
# The score for k value of 6 was 0.6
# The score for k value of 7 was 0.5333333333333333
# The score for k value of 8 was 0.4666666666666667
# The score for k value of 9 was 0.5333333333333333
# The score for k value of 10 was 0.3333333333333333
# The score for k value of 11 was 0.3333333333333333
# The score for k value of 12 was 0.3333333333333333
# The score for k value of 13 was 0.26666666666666666
# The score for k value of 14 was 0.3333333333333333
# The score for k value of 15 was 0.26666666666666666
# The score for k value of 16 was 0.26666666666666666
# The score for k value of 17 was 0.26666666666666666
# The score for k value of 18 was 0.26666666666666666
# The score for k value of 19 was 0.26666666666666666
# ...

# %% [markdown]
# KNearestNeighbor classifier with normalization using MinMax scaling.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)

print(X_train_scaled)
#X_train.head()

# Interesting. X_train is a pandas dataframe, while the output of the scaler fucntion is an np array

X_test_scaled = scaler.transform(X_test)

# We would not fit the scaling model to both X_train and X_test, since it would result in a mismatch and random values
# Also, if we train the scaler on the test dataset and not the training dataset, there would be "data leakage"

# Now we retrain the KNearNeighbor classifer with the normalized dataset

score_list = []

for k in range(1,20):
    
    knn = KNeighborsClassifier(n_neighbors=k).fit(X_train_scaled, y_train)

    score = knn.score(X_test_scaled, y_test)
    
    score_list.append(score)
    
    print("K value:{}, Score:{:.2f}".format(k, score))

plt.scatter(range(1,20), score_list, marker='o')
plt.show()
# Out:
# [[ 0.27857143  0.41176471  0.49230769  0.72972973]
#  [ 0.35        0.44117647  0.93846154  0.45945946]
#  [ 0.          0.          0.          0.7027027 ]
#  [ 0.27142857  0.52941176  0.50769231  0.37837838]
#  [ 0.31428571  0.41176471  0.46153846  0.67567568]
#  [ 0.2         0.          0.72307692  0.48648649]
#  [ 0.3         0.35294118  0.52307692  0.7027027 ]
#  [ 0.27857143  0.44117647  0.50769231  0.64864865]
#  [ 0.14285714  0.02941176  0.63076923  0.48648649]
#  [ 0.30714286  0.5         0.47692308  0.75675676]
#  [ 0.14285714  0.14705882  0.56923077  0.45945946]
#  [ 0.45714286  0.5         0.8         0.59459459]
#  [ 0.28571429  0.55882353  0.47692308  0.37837838]
#  [ 0.01428571  0.          0.04615385  0.59459459]
#  [ 0.47857143  0.58823529  0.61538462  0.72972973]
#  [ 0.28571429  0.52941176  0.53846154  0.32432432]
#  [ 0.19285714  0.05882353  0.64615385  0.43243243]
#  [ 0.3         0.5         0.53846154  0.83783784]
# ...

# %% [markdown]
# So therefore, for KNN classifier, without normalization, the optimal K value is 1 and the score is 0.6
#                                 While, with normalization, the optimal K value is 5 and the score is 1.

# %%
# Creating a sample binary regression problem dataset
# %matplotlib notebook

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap


from sklearn.datasets import make_regression


plt.title("Sample regression dataset")

X_R1, Y_R1 = make_regression(n_samples=100, n_features=1, noise = 30,n_informative=1, bias=150.0, random_state=0)

plt.scatter(X_R1, Y_R1, marker='o',s=50)
plt.show()

from sklearn.neighbors import KNeighborsRegressor


X_train, X_test, y_train, y_test = train_test_split(X_R1, Y_R1, random_state=0)

knn = KNeighborsRegressor(n_neighbors=5)

knn.fit(X_train, y_train)

score_train = knn.score(X_train, y_train)
score_test = knn.score(X_test, y_test)

print(score_train, score_test)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.744659821473 0.424680085823

# %% [markdown]
# Normalization

# %%
# %matplotlib notebook
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train, y_train)

X_train_s = scaler.transform(X_train)
X_test_s = scaler.transform(X_test)

from sklearn.neighbors import KNeighborsRegressor

score_highest=0

for k in range(1,50):
    knn = KNeighborsRegressor(n_neighbors=k).fit(X_train_s, y_train)

    score_test = knn.score(X_test_s, y_test)
    score_train = knn.score(X_train_s, y_train)
    
    
    if score_test>score_highest:
        k_value = k
        score_highest=score_test
        

print("K: {}, score: {:.2f}".format(k_value,score_highest))

# Just did this to see the normalization on the X_training set
plt.scatter(X_train_s, y_train, marker='o', s=50)
plt.show()
# Out:
# K: 6, score: 0.52
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_R1, Y_R1, random_state=0)

lr = LinearRegression().fit(X_train, y_train)

score = lr.score(X_test,y_test)

print(score)
# Out:
# 0.491596159349

# %%
# %matplotlib notebook
#Linear Regression Plot

plt.title('Linear Regression Plot')
plt.scatter(X_R1, Y_R1, marker='x',s=50)
plt.plot(X_R1, lr.coef_*X_R1 + lr.intercept_, 'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_R1, Y_R1, random_state=0)

ridge = Ridge().fit(X_train, y_train)

print(ridge.score(X_test, y_test))
# Out:
# 0.497333961722

# %% [markdown]
# Normalized Ridge Regression

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

ridge = Ridge().fit(X_train_scaled, y_train)

print(ridge.score(X_test_scaled, y_test))
# Out:
# 0.547704597371

# %% [markdown]
# Normalized ridge regression with regularization

# %%
# %matplotlib notebook
alpha_val=[0,5,10,20,30,40,50,60]
scores = []
for alpha1 in range(0,20):
    ridge = Ridge(alpha=alpha1).fit(X_train_scaled,y_train)
    scores.append(ridge.score(X_test_scaled, y_test))

#plt.xscale('log')    
plt.plot(range(0,20), scores)
plt.show()
print(scores)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0.49233590972846736, 0.54770459737122268, 0.52787136839044924, 0.49082077324088969, 0.45209493718052673, 0.41610632948893256, 0.38389089731617365, 0.35540253960855794, 0.33026870747807086, 0.30805221328084809, 0.28834062252879589, 0.27077254945538209, 0.25504074424762713, 0.24088717105057222, 0.22809595328273183, 0.21648639820377213, 0.2059068441274321, 0.19622948996108547, 0.18734614733616284, 0.17916478647540782]

# %% [markdown]
# # # Polynomial Regression

# %%
# %matplotlib notebook
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)

X_R1_Poly = poly.fit_transform(X_R1)

X_train, X_test, y_train, y_test = train_test_split(X_R1_Poly,Y_R1, random_state=0)


ridge = Ridge(50).fit(X_train, y_train)

ridge.score(X_test, y_test)

plt.title('Polynomial Regression Plot')
plt.scatter(X_R1, Y_R1, marker="x", s=50)
plt.plot(X_R1, ridge.coef_*X_R1+ridge.intercept_, 'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # # Linear Models for Classification

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Kind of a contradictory name but logistic regression is used for classification between binary choices or multiclass target values. Since you take on that logictic function with y belongs to (0,1) at the output.

# %% [markdown]
# Applying it to the fruits dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

fruits = pd.read_table('fruit_data_with_colors.txt')

features = ['height', 'width']
X_fruits_2d = fruits[features]
Y_fruits = fruits['fruit_label']

y_fruits_apple = Y_fruits == 1   # make into a binary problem: apples vs everything else
X_train, X_test, y_train, y_test = (
train_test_split(X_fruits_2d.as_matrix(),
                y_fruits_apple.as_matrix(),
                random_state = 0))


from sklearn.linear_model import LogisticRegression

logr = LogisticRegression(C=100).fit(X_train, y_train)

logr.score(X_test, y_test)

h = int(input('Height of the fruit'))
w = int(input('Width of the fruit'))
          


print('For a height of {} and weight of {}, the prediction is {}'.format(h, w, ['not an apple', 'an apple'][logr.predict([[h,w]])[0]]))
# Out:
# Height of the fruit10
# Width of the fruit7
# For a height of 10 and weight of 7, the prediction is not an apple

# %% [markdown]
# Synthetic dataset

# %%
from sklearn.datasets import make_classification

X_C1, Y_C1 = make_classification(n_samples = 100, n_features = 2, n_redundant=0, n_informative=2, n_clusters_per_class=1,
                                 flip_y=0.1, class_sep = 0.5,random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X_C1, Y_C1)

from sklearn.linear_model import LogisticRegression

for c_1 in [0.1,0.5,1,2,5,10,50,100,1000]:
    logr = LogisticRegression(C=c_1).fit(X_train, y_train)
    print(c_1, logr.score(X_test, y_test))
# Out:
# 0.1 0.8
# 0.5 0.84
# 1 0.84
# 2 0.84
# 5 0.84
# 10 0.88
# 50 0.88
# 100 0.88
# 1000 0.88
